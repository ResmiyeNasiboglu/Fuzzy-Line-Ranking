# %%
import numpy as np
import pandas as pd
import pyodbc

db_yolu = r""
db_yolu1 = db_yolu+r"\14_11_2011.mdb"
baglanti_metni = (
    r"DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};"
    f"DBQ={db_yolu1};"
)

# Bağlantıyı oluştur
conn = pyodbc.connect(baglanti_metni)

# SQL sorgusunu Pandas ile çalıştır
sorgu = "SELECT HAT_KODU,DURAK_ID,Count(CARD_NO) AS BINIS_SAYISI FROM 14_11_2011  GROUP BY HAT_KODU,DURAK_ID"
df = pd.read_sql(sorgu, conn)

csv_file=db_yolu+r"\14_11_2011.csv"
df.to_csv(csv_file, sep=',', encoding='utf-8', index=False, header=True)

# Veriyi kullanmaya başla
print(df[0:5]) # 65-120 satırları göster
# print(df.describe()) # İstatistiksel özet çıkar
# Out:
# C:\Users\deu\AppData\Local\Temp\ipykernel_12996\2429940969.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sorgu, conn)
#   HAT_KODU DURAK_ID  BINIS_SAYISI
# 0    00200    10628            11
# 1    00200    10629             1
# 2    00200    10631             2
# 3    00200    10632             1
# 4    00200    10634             4

# %%
pivot_df=df.pivot_table(index='HAT_KODU', columns='DURAK_ID', values='BINIS_SAYISI', aggfunc='sum')

# %%
sorgu = "SELECT DISTINCT HAT_KODU FROM 14_11_2011"
hatlar = pd.read_sql(sorgu, conn)
csv_file=db_yolu+r"\Hatlar.csv"
hatlar.to_csv(csv_file, sep=',', encoding='utf-8', index=False, header=True)

sorgu = "SELECT DISTINCT DURAK_ID FROM 14_11_2011"
duraklar = pd.read_sql(sorgu, conn)
csv_file=db_yolu+r"\Duraklar.csv"
duraklar.to_csv(csv_file, sep=',', encoding='utf-8', index=False, header=True)
# Out:
# C:\Users\deu\AppData\Local\Temp\ipykernel_12996\2130972342.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   hatlar = pd.read_sql(sorgu, conn)
# C:\Users\deu\AppData\Local\Temp\ipykernel_12996\2130972342.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   duraklar = pd.read_sql(sorgu, conn)

# %%
# Method 1: Simple groupby with max
line_boardings_max = df.groupby('HAT_KODU')['BINIS_SAYISI'].max()
print("Max boardings by route:")
print(line_boardings_max)
csv_file1=db_yolu+r"\14_11_2011_max_binis.csv"
line_boardings_max.to_csv(csv_file1, sep=',', encoding='utf-8', index=True, header=True)
# Out:
# Max boardings by route:
# HAT_KODU
# 00200      82
# 00202     199
# 00204     222
# 00315      75
# 00720     677
#          ...
# 88806     703
# 88807    1036
# 88808      16
# 90029      29
# 99999      58
# Name: BINIS_SAYISI, Length: 368, dtype: int64

# %%
import pandas as pd
import pyodbc

file_yolu = db_yolu+r"\Hatlar.csv"
hatlar1 = pd.read_csv(file_yolu)
file_yolu = db_yolu+r"\Duraklar.csv"
duraklar1 = pd.read_csv(file_yolu)
file_yolu = db_yolu+r"\14_11_2011.csv"
hat_durak_binisler = pd.read_csv(file_yolu)
file_yolu1 = db_yolu+r"\14_11_2011_max_binis.csv"
hat_toplam_binisler = pd.read_csv(file_yolu1)

print(hat_durak_binisler[0:10])
print(hat_toplam_binisler[0:10])
# Out:
#    HAT_KODU  DURAK_ID  BINIS_SAYISI
# 0       200     10628            11
# 1       200     10629             1
# 2       200     10631             2
# 3       200     10632             1
# 4       200     10634             4
# 5       200     10639             1
# 6       200     10640             2
# 7       200     10652             2
# 8       200     10654             1
# 9       200     10664             1
#    HAT_KODU  BINIS_SAYISI
# 0       200            82
# 1       202           199
# 2       204           222
# 3       315            75
# 4       720           677
# 5       725           471
# 6       730           331
# 7       735           104
# 8       744           668
# 9       745           366

# %%
MAX_LINES=hatlar1.values.size
MAX_STOPS=duraklar1.values.size

# 2 boyutlu array'e dönüştürme
hat_durak_matrisi = pivot_df.to_numpy()
LS=np.zeros((MAX_LINES,MAX_STOPS))
for i in range(MAX_LINES):
    for j in range(MAX_STOPS):
        LS[i,j] = hat_durak_matrisi[i][j] if hat_durak_matrisi[i][j]>0 else 0

#print(LS)

# %%
# Hatların ağırlıkları (toplam yolcu sayısına göre)
LW=np.zeros(MAX_LINES)   # Hatın ağırlığı
LW1=np.zeros(MAX_LINES)  # Hatın toplam yolcu sayısı
#LS = hat_durak_matrisi

# Hatlar bazlı toplam yolcu sayısı hesaplanması
for i in range(MAX_LINES):
    LW1[i]=LS[i].sum()

# Hatların ağırlıklarının hesaplanması
bb=LW1.sum()
for i in range(MAX_LINES):
    LW[i]=LW1[i]/bb

# FLS matrisinin oluşumu
FLS= np.zeros((MAX_LINES, MAX_STOPS))
for i in range(MAX_LINES):
    cc=LS[i].max()
    for j in range(MAX_STOPS):
        FLS[i,j]=LS[i,j]/cc


# S matrisinin oluşumu
S= np.zeros((MAX_LINES, MAX_LINES))
for i in range(MAX_LINES):
    print(f"Similarity vector of Line{i} hesaplanıyor...")
    for k in range(MAX_LINES):
        if k<=i: continue
        t1=0
        t2=0
        for j in range(MAX_STOPS):
            t1+=min(FLS[i,j],FLS[k,j])
            t2+=max(FLS[i,j],FLS[k,j])

        S[i,k]=t1/t2

for i in range(MAX_LINES):
    S[i,i]=1
    for k in range(i):
        S[i,k]=S[k,i]
# Out:
# Similarity vector of Line0 hesaplanıyor...
# Similarity vector of Line1 hesaplanıyor...
# Similarity vector of Line2 hesaplanıyor...
# Similarity vector of Line3 hesaplanıyor...
# Similarity vector of Line4 hesaplanıyor...
# Similarity vector of Line5 hesaplanıyor...
# Similarity vector of Line6 hesaplanıyor...
# Similarity vector of Line7 hesaplanıyor...
# Similarity vector of Line8 hesaplanıyor...
# Similarity vector of Line9 hesaplanıyor...
# Similarity vector of Line10 hesaplanıyor...
# Similarity vector of Line11 hesaplanıyor...
# Similarity vector of Line12 hesaplanıyor...
# Similarity vector of Line13 hesaplanıyor...
# Similarity vector of Line14 hesaplanıyor...
# Similarity vector of Line15 hesaplanıyor...
# Similarity vector of Line16 hesaplanıyor...
# Similarity vector of Line17 hesaplanıyor...
# Similarity vector of Line18 hesaplanıyor...
# Similarity vector of Line19 hesaplanıyor...
# Similarity vector of Line20 hesaplanıyor...
# Similarity vector of Line21 hesaplanıyor...
# Similarity vector of Line22 hesaplanıyor...
# Similarity vector of Line23 hesaplanıyor...
# Similarity vector of Line24 hesaplanıyor...
# Similarity vector of Line25 hesaplanıyor...
# Similarity vector of Line26 hesaplanıyor...
# Similarity vector of Line27 hesaplanıyor...
# Similarity vector of Line28 hesaplanıyor...
# Similarity vector of Line29 hesaplanıyor...
# Similarity vector of Line30 hesaplanıyor...
# Similarity vector of Line31 hesaplanıyor...
# Similarity vector of Line32 hesaplanıyor...
# Similarity vector of Line33 hesaplanıyor...
# Similarity vector of Line34 hesaplanıyor...
# Similarity vector of Line35 hesaplanıyor...
# Similarity vector of Line36 hesaplanıyor...
# Similarity vector of Line37 hesaplanıyor...
# Similarity vector of Line38 hesaplanıyor...
# Similarity vector of Line39 hesaplanıyor...
# Similarity vector of Line40 hesaplanıyor...
# Similarity vector of Line41 hesaplanıyor...
# Similarity vector of Line42 hesaplanıyor...
# Similarity vector of Line43 hesaplanıyor...
# Similarity vector of Line44 hesaplanıyor...
# Similarity vector of Line45 hesaplanıyor...
# Similarity vector of Line46 hesaplanıyor...
# Similarity vector of Line47 hesaplanıyor...
# Similarity vector of Line48 hesaplanıyor...
# Similarity vector of Line49 hesaplanıyor...
# Similarity vector of Line50 hesaplanıyor...
# Similarity vector of Line51 hesaplanıyor...
# Similarity vector of Line52 hesaplanıyor...
# Similarity vector of Line53 hesaplanıyor...
# Similarity vector of Line54 hesaplanıyor...
# Similarity vector of Line55 hesaplanıyor...
# Similarity vector of Line56 hesaplanıyor...
# Similarity vector of Line57 hesaplanıyor...
# Similarity vector of Line58 hesaplanıyor...
# Similarity vector of Line59 hesaplanıyor...
# Similarity vector of Line60 hesaplanıyor...
# Similarity vector of Line61 hesaplanıyor...
# Similarity vector of Line62 hesaplanıyor...
# Similarity vector of Line63 hesaplanıyor...
# Similarity vector of Line64 hesaplanıyor...
# Similarity vector of Line65 hesaplanıyor...
# Similarity vector of Line66 hesaplanıyor...
# Similarity vector of Line67 hesaplanıyor...
# Similarity vector of Line68 hesaplanıyor...
# Similarity vector of Line69 hesaplanıyor...
# Similarity vector of Line70 hesaplanıyor...
# Similarity vector of Line71 hesaplanıyor...
# Similarity vector of Line72 hesaplanıyor...
# Similarity vector of Line73 hesaplanıyor...
# Similarity vector of Line74 hesaplanıyor...
# Similarity vector of Line75 hesaplanıyor...
# Similarity vector of Line76 hesaplanıyor...
# Similarity vector of Line77 hesaplanıyor...
# Similarity vector of Line78 hesaplanıyor...
# Similarity vector of Line79 hesaplanıyor...
# Similarity vector of Line80 hesaplanıyor...
# Similarity vector of Line81 hesaplanıyor...
# Similarity vector of Line82 hesaplanıyor...
# Similarity vector of Line83 hesaplanıyor...
# Similarity vector of Line84 hesaplanıyor...
# Similarity vector of Line85 hesaplanıyor...
# Similarity vector of Line86 hesaplanıyor...
# Similarity vector of Line87 hesaplanıyor...
# Similarity vector of Line88 hesaplanıyor...
# Similarity vector of Line89 hesaplanıyor...
# Similarity vector of Line90 hesaplanıyor...
# Similarity vector of Line91 hesaplanıyor...
# Similarity vector of Line92 hesaplanıyor...
# Similarity vector of Line93 hesaplanıyor...
# Similarity vector of Line94 hesaplanıyor...
# Similarity vector of Line95 hesaplanıyor...
# Similarity vector of Line96 hesaplanıyor...
# Similarity vector of Line97 hesaplanıyor...
# Similarity vector of Line98 hesaplanıyor...
# Similarity vector of Line99 hesaplanıyor...
# Similarity vector of Line100 hesaplanıyor...
# Similarity vector of Line101 hesaplanıyor...
# Similarity vector of Line102 hesaplanıyor...
# Similarity vector of Line103 hesaplanıyor...
# Similarity vector of Line104 hesaplanıyor...
# Similarity vector of Line105 hesaplanıyor...
# Similarity vector of Line106 hesaplanıyor...
# Similarity vector of Line107 hesaplanıyor...
# Similarity vector of Line108 hesaplanıyor...
# Similarity vector of Line109 hesaplanıyor...
# Similarity vector of Line110 hesaplanıyor...
# Similarity vector of Line111 hesaplanıyor...
# Similarity vector of Line112 hesaplanıyor...
# Similarity vector of Line113 hesaplanıyor...
# Similarity vector of Line114 hesaplanıyor...
# Similarity vector of Line115 hesaplanıyor...
# Similarity vector of Line116 hesaplanıyor...
# Similarity vector of Line117 hesaplanıyor...
# Similarity vector of Line118 hesaplanıyor...
# Similarity vector of Line119 hesaplanıyor...
# Similarity vector of Line120 hesaplanıyor...
# Similarity vector of Line121 hesaplanıyor...
# Similarity vector of Line122 hesaplanıyor...
# Similarity vector of Line123 hesaplanıyor...
# Similarity vector of Line124 hesaplanıyor...
# Similarity vector of Line125 hesaplanıyor...
# Similarity vector of Line126 hesaplanıyor...
# Similarity vector of Line127 hesaplanıyor...
# Similarity vector of Line128 hesaplanıyor...
# Similarity vector of Line129 hesaplanıyor...
# Similarity vector of Line130 hesaplanıyor...
# Similarity vector of Line131 hesaplanıyor...
# Similarity vector of Line132 hesaplanıyor...
# Similarity vector of Line133 hesaplanıyor...
# Similarity vector of Line134 hesaplanıyor...
# Similarity vector of Line135 hesaplanıyor...
# Similarity vector of Line136 hesaplanıyor...
# Similarity vector of Line137 hesaplanıyor...
# Similarity vector of Line138 hesaplanıyor...
# Similarity vector of Line139 hesaplanıyor...
# Similarity vector of Line140 hesaplanıyor...
# Similarity vector of Line141 hesaplanıyor...
# Similarity vector of Line142 hesaplanıyor...
# Similarity vector of Line143 hesaplanıyor...
# Similarity vector of Line144 hesaplanıyor...
# Similarity vector of Line145 hesaplanıyor...
# Similarity vector of Line146 hesaplanıyor...
# Similarity vector of Line147 hesaplanıyor...
# Similarity vector of Line148 hesaplanıyor...
# Similarity vector of Line149 hesaplanıyor...
# Similarity vector of Line150 hesaplanıyor...
# Similarity vector of Line151 hesaplanıyor...
# Similarity vector of Line152 hesaplanıyor...
# Similarity vector of Line153 hesaplanıyor...
# Similarity vector of Line154 hesaplanıyor...
# Similarity vector of Line155 hesaplanıyor...
# Similarity vector of Line156 hesaplanıyor...
# Similarity vector of Line157 hesaplanıyor...
# Similarity vector of Line158 hesaplanıyor...
# Similarity vector of Line159 hesaplanıyor...
# Similarity vector of Line160 hesaplanıyor...
# Similarity vector of Line161 hesaplanıyor...
# Similarity vector of Line162 hesaplanıyor...
# Similarity vector of Line163 hesaplanıyor...
# Similarity vector of Line164 hesaplanıyor...
# Similarity vector of Line165 hesaplanıyor...
# Similarity vector of Line166 hesaplanıyor...
# Similarity vector of Line167 hesaplanıyor...
# Similarity vector of Line168 hesaplanıyor...
# Similarity vector of Line169 hesaplanıyor...
# Similarity vector of Line170 hesaplanıyor...
# Similarity vector of Line171 hesaplanıyor...
# Similarity vector of Line172 hesaplanıyor...
# Similarity vector of Line173 hesaplanıyor...
# Similarity vector of Line174 hesaplanıyor...
# Similarity vector of Line175 hesaplanıyor...
# Similarity vector of Line176 hesaplanıyor...
# Similarity vector of Line177 hesaplanıyor...
# Similarity vector of Line178 hesaplanıyor...
# Similarity vector of Line179 hesaplanıyor...
# Similarity vector of Line180 hesaplanıyor...
# Similarity vector of Line181 hesaplanıyor...
# Similarity vector of Line182 hesaplanıyor...
# Similarity vector of Line183 hesaplanıyor...
# Similarity vector of Line184 hesaplanıyor...
# Similarity vector of Line185 hesaplanıyor...
# Similarity vector of Line186 hesaplanıyor...
# Similarity vector of Line187 hesaplanıyor...
# Similarity vector of Line188 hesaplanıyor...
# Similarity vector of Line189 hesaplanıyor...
# Similarity vector of Line190 hesaplanıyor...
# Similarity vector of Line191 hesaplanıyor...
# Similarity vector of Line192 hesaplanıyor...
# Similarity vector of Line193 hesaplanıyor...
# Similarity vector of Line194 hesaplanıyor...
# Similarity vector of Line195 hesaplanıyor...
# Similarity vector of Line196 hesaplanıyor...
# Similarity vector of Line197 hesaplanıyor...
# Similarity vector of Line198 hesaplanıyor...
# Similarity vector of Line199 hesaplanıyor...
# Similarity vector of Line200 hesaplanıyor...
# Similarity vector of Line201 hesaplanıyor...
# Similarity vector of Line202 hesaplanıyor...
# Similarity vector of Line203 hesaplanıyor...
# Similarity vector of Line204 hesaplanıyor...
# Similarity vector of Line205 hesaplanıyor...
# Similarity vector of Line206 hesaplanıyor...
# Similarity vector of Line207 hesaplanıyor...
# Similarity vector of Line208 hesaplanıyor...
# Similarity vector of Line209 hesaplanıyor...
# Similarity vector of Line210 hesaplanıyor...
# Similarity vector of Line211 hesaplanıyor...
# Similarity vector of Line212 hesaplanıyor...
# Similarity vector of Line213 hesaplanıyor...
# Similarity vector of Line214 hesaplanıyor...
# Similarity vector of Line215 hesaplanıyor...
# Similarity vector of Line216 hesaplanıyor...
# Similarity vector of Line217 hesaplanıyor...
# Similarity vector of Line218 hesaplanıyor...
# Similarity vector of Line219 hesaplanıyor...
# Similarity vector of Line220 hesaplanıyor...
# Similarity vector of Line221 hesaplanıyor...
# Similarity vector of Line222 hesaplanıyor...
# Similarity vector of Line223 hesaplanıyor...
# Similarity vector of Line224 hesaplanıyor...
# Similarity vector of Line225 hesaplanıyor...
# Similarity vector of Line226 hesaplanıyor...
# Similarity vector of Line227 hesaplanıyor...
# Similarity vector of Line228 hesaplanıyor...
# Similarity vector of Line229 hesaplanıyor...
# Similarity vector of Line230 hesaplanıyor...
# Similarity vector of Line231 hesaplanıyor...
# Similarity vector of Line232 hesaplanıyor...
# Similarity vector of Line233 hesaplanıyor...
# Similarity vector of Line234 hesaplanıyor...
# Similarity vector of Line235 hesaplanıyor...
# Similarity vector of Line236 hesaplanıyor...
# Similarity vector of Line237 hesaplanıyor...
# Similarity vector of Line238 hesaplanıyor...
# Similarity vector of Line239 hesaplanıyor...
# Similarity vector of Line240 hesaplanıyor...
# Similarity vector of Line241 hesaplanıyor...
# Similarity vector of Line242 hesaplanıyor...
# Similarity vector of Line243 hesaplanıyor...
# Similarity vector of Line244 hesaplanıyor...
# Similarity vector of Line245 hesaplanıyor...
# Similarity vector of Line246 hesaplanıyor...
# Similarity vector of Line247 hesaplanıyor...
# Similarity vector of Line248 hesaplanıyor...
# Similarity vector of Line249 hesaplanıyor...
# Similarity vector of Line250 hesaplanıyor...
# Similarity vector of Line251 hesaplanıyor...
# Similarity vector of Line252 hesaplanıyor...
# Similarity vector of Line253 hesaplanıyor...
# Similarity vector of Line254 hesaplanıyor...
# Similarity vector of Line255 hesaplanıyor...
# Similarity vector of Line256 hesaplanıyor...
# Similarity vector of Line257 hesaplanıyor...
# Similarity vector of Line258 hesaplanıyor...
# Similarity vector of Line259 hesaplanıyor...
# Similarity vector of Line260 hesaplanıyor...
# Similarity vector of Line261 hesaplanıyor...
# Similarity vector of Line262 hesaplanıyor...
# Similarity vector of Line263 hesaplanıyor...
# Similarity vector of Line264 hesaplanıyor...
# Similarity vector of Line265 hesaplanıyor...
# Similarity vector of Line266 hesaplanıyor...
# Similarity vector of Line267 hesaplanıyor...
# Similarity vector of Line268 hesaplanıyor...
# Similarity vector of Line269 hesaplanıyor...
# Similarity vector of Line270 hesaplanıyor...
# Similarity vector of Line271 hesaplanıyor...
# Similarity vector of Line272 hesaplanıyor...
# Similarity vector of Line273 hesaplanıyor...
# Similarity vector of Line274 hesaplanıyor...
# Similarity vector of Line275 hesaplanıyor...
# Similarity vector of Line276 hesaplanıyor...
# Similarity vector of Line277 hesaplanıyor...
# Similarity vector of Line278 hesaplanıyor...
# Similarity vector of Line279 hesaplanıyor...
# Similarity vector of Line280 hesaplanıyor...
# Similarity vector of Line281 hesaplanıyor...
# Similarity vector of Line282 hesaplanıyor...
# Similarity vector of Line283 hesaplanıyor...
# Similarity vector of Line284 hesaplanıyor...
# Similarity vector of Line285 hesaplanıyor...
# Similarity vector of Line286 hesaplanıyor...
# Similarity vector of Line287 hesaplanıyor...
# Similarity vector of Line288 hesaplanıyor...
# Similarity vector of Line289 hesaplanıyor...
# Similarity vector of Line290 hesaplanıyor...
# Similarity vector of Line291 hesaplanıyor...
# Similarity vector of Line292 hesaplanıyor...
# Similarity vector of Line293 hesaplanıyor...
# Similarity vector of Line294 hesaplanıyor...
# Similarity vector of Line295 hesaplanıyor...
# Similarity vector of Line296 hesaplanıyor...
# Similarity vector of Line297 hesaplanıyor...
# Similarity vector of Line298 hesaplanıyor...
# Similarity vector of Line299 hesaplanıyor...
# Similarity vector of Line300 hesaplanıyor...
# Similarity vector of Line301 hesaplanıyor...
# Similarity vector of Line302 hesaplanıyor...
# Similarity vector of Line303 hesaplanıyor...
# Similarity vector of Line304 hesaplanıyor...
# Similarity vector of Line305 hesaplanıyor...
# Similarity vector of Line306 hesaplanıyor...
# Similarity vector of Line307 hesaplanıyor...
# Similarity vector of Line308 hesaplanıyor...
# Similarity vector of Line309 hesaplanıyor...
# Similarity vector of Line310 hesaplanıyor...
# Similarity vector of Line311 hesaplanıyor...
# Similarity vector of Line312 hesaplanıyor...
# Similarity vector of Line313 hesaplanıyor...
# Similarity vector of Line314 hesaplanıyor...
# Similarity vector of Line315 hesaplanıyor...
# Similarity vector of Line316 hesaplanıyor...
# Similarity vector of Line317 hesaplanıyor...
# Similarity vector of Line318 hesaplanıyor...
# Similarity vector of Line319 hesaplanıyor...
# Similarity vector of Line320 hesaplanıyor...
# Similarity vector of Line321 hesaplanıyor...
# Similarity vector of Line322 hesaplanıyor...
# Similarity vector of Line323 hesaplanıyor...
# Similarity vector of Line324 hesaplanıyor...
# Similarity vector of Line325 hesaplanıyor...
# Similarity vector of Line326 hesaplanıyor...
# Similarity vector of Line327 hesaplanıyor...
# Similarity vector of Line328 hesaplanıyor...
# Similarity vector of Line329 hesaplanıyor...
# Similarity vector of Line330 hesaplanıyor...
# Similarity vector of Line331 hesaplanıyor...
# Similarity vector of Line332 hesaplanıyor...
# Similarity vector of Line333 hesaplanıyor...
# Similarity vector of Line334 hesaplanıyor...
# Similarity vector of Line335 hesaplanıyor...
# Similarity vector of Line336 hesaplanıyor...
# Similarity vector of Line337 hesaplanıyor...
# Similarity vector of Line338 hesaplanıyor...
# Similarity vector of Line339 hesaplanıyor...
# Similarity vector of Line340 hesaplanıyor...
# Similarity vector of Line341 hesaplanıyor...
# Similarity vector of Line342 hesaplanıyor...
# Similarity vector of Line343 hesaplanıyor...
# Similarity vector of Line344 hesaplanıyor...
# Similarity vector of Line345 hesaplanıyor...
# Similarity vector of Line346 hesaplanıyor...
# Similarity vector of Line347 hesaplanıyor...
# Similarity vector of Line348 hesaplanıyor...
# Similarity vector of Line349 hesaplanıyor...
# Similarity vector of Line350 hesaplanıyor...
# Similarity vector of Line351 hesaplanıyor...
# Similarity vector of Line352 hesaplanıyor...
# Similarity vector of Line353 hesaplanıyor...
# Similarity vector of Line354 hesaplanıyor...
# Similarity vector of Line355 hesaplanıyor...
# Similarity vector of Line356 hesaplanıyor...
# Similarity vector of Line357 hesaplanıyor...
# Similarity vector of Line358 hesaplanıyor...
# Similarity vector of Line359 hesaplanıyor...
# Similarity vector of Line360 hesaplanıyor...
# Similarity vector of Line361 hesaplanıyor...
# Similarity vector of Line362 hesaplanıyor...
# Similarity vector of Line363 hesaplanıyor...
# Similarity vector of Line364 hesaplanıyor...
# Similarity vector of Line365 hesaplanıyor...
# Similarity vector of Line366 hesaplanıyor...
# Similarity vector of Line367 hesaplanıyor...

# %%
"""
# Hatların toplam yolcu sayısı ve ağırlıklarını yazdıralım
print(f"       Toplam biniş sayısı   Ağırlık")
for i in range(MAX_LINES):
    print(f"Line{i+1} : {LW1[i]:4.0f}    {LW[i]:.3f}")
"""
# Out:
# '\n# Hatların toplam yolcu sayısı ve ağırlıklarını yazdıralım\nprint(f"       Toplam biniş sayısı   Ağırlık")\nfor i in range(MAX_LINES):\n    print(f"Line{i+1} : {LW1[i]:4.0f}    {LW[i]:.3f}")\n'

# %%
"""
# Hat-durak LS değerlerini yazdıralım
for i in range(MAX_LINES):
    print("Line",i+1," = (", end="")
    for j in range(MAX_STOPS):
        if LS[i,j]>0:
            print(f"({j+1},{LS[i,j]:.0f})",end=",")
    print()
"""
# Out:
# '\n# Hat-durak LS değerlerini yazdıralım\nfor i in range(MAX_LINES):\n    print("Line",i+1," = (", end="")\n    for j in range(MAX_STOPS):\n        if LS[i,j]>0:\n            print(f"({j+1},{LS[i,j]:.0f})",end=",")\n    print()\n'

# %%
"""
# Hat-durak FLS değerlerini yazdıralım
for i in range(MAX_LINES):
    print("Line",i+1," = (", end="")
    for j in range(MAX_STOPS):
        if FLS[i,j]>0:
            print(f"({j+1},{FLS[i,j]:.3f})",end=",")
    print()
"""
# Out:
# '\n# Hat-durak FLS değerlerini yazdıralım\nfor i in range(MAX_LINES):\n    print("Line",i+1," = (", end="")\n    for j in range(MAX_STOPS):\n        if FLS[i,j]>0:\n            print(f"({j+1},{FLS[i,j]:.3f})",end=",")\n    print()\n'

# %%
"""
# Hatlararası similarity matrisini yazdıralım
for i in range(MAX_LINES):
    #print("Line",i+1," = ", end="")
    for j in range(MAX_LINES):
        print(f" {S[i,j]:.3f}",end=",")
    print()
"""
# Out:
# '\n# Hatlararası similarity matrisini yazdıralım\nfor i in range(MAX_LINES):\n    #print("Line",i+1," = ", end="")\n    for j in range(MAX_LINES):\n        print(f" {S[i,j]:.3f}",end=",")\n    print()\n'

# %%
# Hatların benzerliklerini satırlar boyunca topla (Kendisi hariç)
satir_toplamlari = np.sum(S, axis=1)-1

# Yazdır
#for i in range(MAX_LINES):
#    print(f"{satir_toplamlari[i]:.3f}")

# Hat etkileşim ağırlıkları (diğer hatlarla ilişkilerin oranları hesaplanıyor). 
# Köşegen dikkate alınmıyor.

w=np.zeros((MAX_LINES,MAX_LINES))

for i in range(MAX_LINES):
    for j in range(MAX_LINES):
        if j==i:
            #print(f".....",end=",")
            continue
        
        if satir_toplamlari[i]>0:
            w[i,j]=S[i,j]/satir_toplamlari[i]  
        else: w[i,j] = 0

        #print(f"{w[i,j]:5.3f}",end=",")

    #print()
#print(np.sum(w, axis=1))

# %%
#satir_toplamlari

# %%
import math

# Hatların skorlarının hesaplanması
PR0=np.ones(MAX_LINES)/MAX_LINES
PR=PR0.copy()

d=0.7
eps=0.001
fark=9999
iter=0
while fark > eps:
    for i in range(MAX_LINES):
        s=0
        for j in range(MAX_LINES):
            if j==i:
                continue
            s+=PR[j]*w[j,i]   
    
        PR[i]=(1-d)+d*s       # *LW[i]
        #print(f"{PR[i]:.3f} ",end="")
    
    fark=0
    for i in range(MAX_LINES):
        fark+=abs(PR[i]-PR0[i])
    
    #print(f"Iterasyon = {iter},  fark = {fark}")
    PR0=PR.copy()
    iter+=1

desc_indices = np.argsort(PR)[::-1]
sorted_values = PR[desc_indices]
#print(f"Descending Indices: {desc_indices}")
#print(f"Sorted Values:      {sorted_values}")

sorted_ranks=pd.DataFrame({'Line No':desc_indices,'Rank Score':sorted_values})
print(sorted_ranks[:20])
# Out:
#     Line No  Rank Score
# 0       366    2.122679
# 1       347    2.122679
# 2       346    2.122679
# 3       314    2.122679
# 4       313    2.122679
# 5        88    2.122675
# 6        17    2.073537
# 7       280    1.911132
# 8       260    1.911074
# 9       265    1.877689
# 10      150    1.834726
# 11      109    1.829456
# 12      264    1.796347
# 13      266    1.755088
# 14      263    1.747381
# 15      175    1.703722
# 16       10    1.686873
# 17       36    1.673654
# 18      272    1.666704
# 19      248    1.605197

# %%
sorted_ranks.to_csv(db_yolu+r"\FLR İzmir results.txt", sep='\t', index=False)

# %%
# Out:
# 1.1775103497638404
# 0.0
# 1.0

# %%
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# 1. Yönlü Çizgeyi Oluştur (Directed Graph)
G = nx.DiGraph()

# 3. Bulanık Mantıkla Belirlenen Ağırlıklı Kenarları Ekle
# weights: (Kaynak, Hedef, Bulanık Etki Ağırlığı)
# Önceki adımda hesapladığımız normalize edilmiş değerleri kullanıyoruz

# 2. Düğümleri Tanımla
# Daha hızlı ve temiz kenar oluşturma
MAX_LINES=20     #Deneme

edges = [(i, j, w[i, j]) for i in range(MAX_LINES)   
         for j in range(MAX_LINES)            
         if i != j and w[i, j] > 0] # Sadece ağırlığı olanları ekle

G.add_weighted_edges_from(edges)

# 2. Analiz: PageRank (TransitRank)
#ranks = nx.pagerank(G, alpha=0.85, weight='weight')
scaling_factor = 3000 # Boyutları belirginleştirmek için çarpan

# 3. Görselleştirme
fig, ax = plt.subplots(figsize=(14, 9))
pos = nx.spring_layout(G, seed=42)

# 2. Kapasiteleri Tanımla
# Kapasiteleri görselde düğüm boyutu için kullanacağız

capacities = {i: LW1[i] for i in range(MAX_LINES)}

# Düğümleri Çiz
node_sizes = [PR[node] * scaling_factor for node in G.nodes()]
nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, 
                               node_color=[capacities[n] for n in G.nodes()], 
                               cmap=plt.cm.Blues, alpha=0.9, edgecolors="black")

# Kenarları Çiz
weights = [G[u][v]['weight'] * 100 for u, v in G.edges()]
nx.draw_networkx_edges(G, pos, width=weights, edge_color='gray', 
                       arrowsize=30, alpha=0.5, connectionstyle='arc3,rad=0.15')

# Etiketler
nx.draw_networkx_labels(G, pos, font_size=11, font_weight='bold')

# 5. Renk Çubuğu (Kapasite İçin)
plt.colorbar(nodes, label='Total Daily Boardings', pad=0.1, shrink=0.8)

plt.title("Fuzzy Lines Graph with Fuzzy Interaction Edges", pad=20, fontsize=15)
plt.axis('off')
plt.savefig(db_yolu+r"\LineRank_grafigi.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Out:
# array([[1.        , 0.24202673, 0.25464763, ..., 0.        , 0.17231638,
#         0.        ],
#        [0.24202673, 1.        , 0.34097026, ..., 0.        , 0.05956113,
#         0.        ],
#        [0.25464763, 0.34097026, 1.        , ..., 0.        , 0.08769448,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.17231638, 0.05956113, 0.08769448, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ]])
